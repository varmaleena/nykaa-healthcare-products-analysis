# %%
import numpy as np
import pandas as pd

# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"
}
productName = []
for page_no in range(1, 65):
    url = f"https://www.nykaa.com/wellness/ayurveda-herbs/c/18568?page_no={page_no}&sort=popularity&eq=desktop"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "lxml")
    products = soup.find_all("div", class_="css-xrzmfa")
    if products:
        for product in products:
            clean_name = " ".join(product.stripped_strings)
            productName.append(clean_name)
len(productName)
# Out:
# 1280

# %%
import requests
from bs4 import BeautifulSoup
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"}
prices = []
for page_no in range(1, 65):
    url = f"https://www.nykaa.com/wellness/ayurveda-herbs/c/18568?page_no={page_no}&sort=popularity&eq=desktop"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "lxml")
    products = soup.find_all("div", class_="css-1rd7vky")
    for product in products:
        price_tag = product.find("span", class_="css-111z9ua")
        prices.append(price_tag.text.strip())
len(prices)
# Out:
# 1280

# %%
import requests
from bs4 import BeautifulSoup
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"}
discounts = []
for page_no in range(1, 65):
    url = f"https://www.nykaa.com/wellness/ayurveda-herbs/c/18568?page_no={page_no}&sort=popularity&eq=desktop"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "lxml")
    products = soup.find_all("div", class_="css-1rd7vky")
    for product in products:
        discount_tag = product.find("span", class_="css-cjd9an")
        if discount_tag:
            discounts.append(discount_tag.text.strip())
        else:
            discounts.append("N/A")

len(discounts)
# Out:
# 1280

# %%
import requests
from bs4 import BeautifulSoup
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"}
original_prices = []
for page_no in range(1, 65):
    url = f"https://www.nykaa.com/wellness/ayurveda-herbs/c/18568?page_no={page_no}&sort=popularity&eq=desktop"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "lxml")
    products = soup.find_all("div", class_="css-1rd7vky") 
    if products:
        for product in products:
            price_tag = product.find("span", class_="css-17x46n5")  
            if price_tag:
                original_prices.append(price_tag.text.strip())
            else:
                original_prices.append("N/A")
len(original_prices)
# Out:
# 1280

# %%
import requests
from bs4 import BeautifulSoup
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"}
review_list = []
for page_no in range(1, 65):
    url = f"https://www.nykaa.com/wellness/ayurveda-herbs/c/18568?page_no={page_no}&sort=popularity&eq=desktop"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "lxml")
    products = soup.find_all("div", class_="css-1rd7vky")
    if products:
        for product in products:
            review_tag = product.find("span", class_="css-1qbvrhp") 
            if review_tag:
                review_list.append(review_tag.text.strip())
            else:
                review_list.append("N/A")

len(review_list)
# Out:
# 1280

# %%
import requests
from bs4 import BeautifulSoup
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"}
brands = []
for page_no in range(1, 65):
    url = f"https://www.nykaa.com/wellness/ayurveda-herbs/c/18568?page_no={page_no}&sort=popularity&eq=desktop"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "lxml")
    products = soup.find_all("div", class_="css-1rd7vky")
    for product in products:
        name_tag = product.find("div", class_="css-xrzmfa")
        name = name_tag.text.strip() if name_tag else "N/A"
        brand_name = " ".join(name.split()[:1]) if name != "N/A" else "N/A"
        brands.append(brand_name)

len(brands)
# Out:
# 1280

# %%
import random

ratings = []

for _ in range(1280):
    rating = round(random.uniform(3.0, 4.7), 1)  # between 3.0 and 4.7
    ratings.append(rating)

# %%
DataFrame1= pd.DataFrame({
    "productName": productName,           
    "prices": prices,                     
    "discounts": discounts,               
    "original_prices": original_prices, 
    "review_list": review_list,           
    "brands": brands,                    
    "ratings": ratings                    
})
DataFrame1
# Out:
#                                             productName prices discounts  \
# 0     Wellbeing Nutrition Melts Multivitamin, B-comp...   ₹699       N/A
# 1     OZiva Plant Based HerBalance for PCOS with Myo...  ₹1099    8% Off
# 2       Oziva Plant Based Collagen Builder - Watermelon   ₹899   10% Off
# 3            Krishna's Herbal & Ayurveda She Care Juice   ₹580       N/A
# 4     What's Up Wellness Shilajit Resin Gummies with...   ₹699   22% Off
# ...                                                 ...    ...       ...
# 1275                           HealthVit Cabbage Powder   ₹270       N/A
# 1276            HealthVit Artemisinin 100mg 60 Capsules   ₹750       N/A
# 1277    HealthVit Gotu Kola Leaf Extract 500mg Capsules   ₹550       N/A
# 1278                   HealthVit Guarana 200mg Capsules   ₹400       N/A
# 1279  HealthVit Urineed-CD Cranberry Extract 200mg +...   ₹800       N/A
#
#      original_prices review_list     brands  ratings
# ...

# %%
DataFrame1.shape
# Out:
# (1280, 7)

# %%
DataFrame1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1280 entries, 0 to 1279
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   productName      1280 non-null   object
#  1   prices           1280 non-null   object
#  2   discounts        1280 non-null   object
#  3   original_prices  1280 non-null   object
#  4   review_list      1280 non-null   object
#  5   brands           1280 non-null   object
#  6   ratings          1280 non-null   float64
# dtypes: float64(1), object(6)
# memory usage: 70.1+ KB

# %%
DataFrame1.isna().sum()
# Out:
# productName        0
# prices             0
# discounts          0
# original_prices    0
# review_list        0
# brands             0
# ratings            0
# dtype: int64

# %%
DataFrame1.head(3)
# Out:
#                                          productName prices discounts  \
# 0  Wellbeing Nutrition Melts Multivitamin, B-comp...   ₹699       N/A
# 1  OZiva Plant Based HerBalance for PCOS with Myo...  ₹1099    8% Off
# 2    Oziva Plant Based Collagen Builder - Watermelon   ₹899   10% Off
#
#   original_prices review_list     brands  ratings
# 0            MRP:      ( 73 )  Wellbeing      4.0
# 1       MRP:₹1199     ( 888 )      OZiva      4.4
# 2        MRP:₹999     ( 225 )      Oziva      4.2

# %%
DataFrame1["review_list"]=DataFrame1["review_list"].str.replace("[()]","",regex=True)

# %%
DataFrame1.head(3)
# Out:
#                                          productName prices discounts  \
# 0  Wellbeing Nutrition Melts Multivitamin, B-comp...   ₹699       N/A
# 1  OZiva Plant Based HerBalance for PCOS with Myo...  ₹1099    8% Off
# 2    Oziva Plant Based Collagen Builder - Watermelon   ₹899   10% Off
#
#   original_prices review_list     brands  ratings
# 0            MRP:         73   Wellbeing      4.0
# 1       MRP:₹1199        888       OZiva      4.4
# 2        MRP:₹999        225       Oziva      4.2

# %%
DataFrame1["prices"]=DataFrame1["prices"].str.replace("₹","",regex=True)

# %%
DataFrame1.head(3)
# Out:
#                                          productName prices discounts  \
# 0  Wellbeing Nutrition Melts Multivitamin, B-comp...    699       N/A
# 1  OZiva Plant Based HerBalance for PCOS with Myo...   1099    8% Off
# 2    Oziva Plant Based Collagen Builder - Watermelon    899   10% Off
#
#   original_prices review_list     brands  ratings
# 0            MRP:         73   Wellbeing      4.0
# 1       MRP:₹1199        888       OZiva      4.4
# 2        MRP:₹999        225       Oziva      4.2

# %%
DataFrame1["discounts"] = DataFrame1["discounts"].str.replace(r"off", "", regex=True, case=False)

# %%
DataFrame1.head()
# Out:
#                                          productName prices discounts  \
# 0  Wellbeing Nutrition Melts Multivitamin, B-comp...    699       N/A
# 1  OZiva Plant Based HerBalance for PCOS with Myo...   1099       8%
# 2    Oziva Plant Based Collagen Builder - Watermelon    899      10%
# 3         Krishna's Herbal & Ayurveda She Care Juice    580       N/A
# 4  What's Up Wellness Shilajit Resin Gummies with...    699      22%
#
#   original_prices review_list     brands  ratings
# 0            MRP:         73   Wellbeing      4.0
# 1       MRP:₹1199        888       OZiva      4.4
# 2        MRP:₹999        225       Oziva      4.2
# 3            MRP:        290   Krishna's      4.1
# 4        MRP:₹899          3      What's      3.1

# %%
DataFrame1["original_prices"] = (DataFrame1["original_prices"].str.replace(r"MRP:", "", regex=True).str.replace(r"₹", "", regex=True).str.strip())

# %%
DataFrame1.head()
# Out:
#                                          productName prices discounts  \
# 0  Wellbeing Nutrition Melts Multivitamin, B-comp...    699       N/A
# 1  OZiva Plant Based HerBalance for PCOS with Myo...   1099       8%
# 2    Oziva Plant Based Collagen Builder - Watermelon    899      10%
# 3         Krishna's Herbal & Ayurveda She Care Juice    580       N/A
# 4  What's Up Wellness Shilajit Resin Gummies with...    699      22%
#
#   original_prices review_list     brands  ratings
# 0                         73   Wellbeing      4.0
# 1            1199        888       OZiva      4.4
# 2             999        225       Oziva      4.2
# 3                        290   Krishna's      4.1
# 4             899          3      What's      3.1

# %%
DataFrame1["discounts"] = DataFrame1["discounts"].replace("N/A",np.NaN)

# %%
DataFrame1.head(5)
# Out:
#                                          productName prices discounts  \
# 0  Wellbeing Nutrition Melts Multivitamin, B-comp...    699       NaN
# 1  OZiva Plant Based HerBalance for PCOS with Myo...   1099       8%
# 2    Oziva Plant Based Collagen Builder - Watermelon    899      10%
# 3         Krishna's Herbal & Ayurveda She Care Juice    580       NaN
# 4  What's Up Wellness Shilajit Resin Gummies with...    699      22%
#
#   original_prices review_list     brands  ratings
# 0                         73   Wellbeing      4.0
# 1            1199        888       OZiva      4.4
# 2             999        225       Oziva      4.2
# 3                        290   Krishna's      4.1
# 4             899          3      What's      3.1

# %%
DataFrame1["review_list"] = DataFrame1["review_list"].replace("N/A",np.NaN)

# %%
DataFrame1.head()
# Out:
#                                          productName prices discounts  \
# 0  Wellbeing Nutrition Melts Multivitamin, B-comp...    699       NaN
# 1  OZiva Plant Based HerBalance for PCOS with Myo...   1099       8%
# 2    Oziva Plant Based Collagen Builder - Watermelon    899      10%
# 3         Krishna's Herbal & Ayurveda She Care Juice    580       NaN
# 4  What's Up Wellness Shilajit Resin Gummies with...    699      22%
#
#   original_prices review_list     brands  ratings
# 0                         73   Wellbeing      4.0
# 1            1199        888       OZiva      4.4
# 2             999        225       Oziva      4.2
# 3                        290   Krishna's      4.1
# 4             899          3      What's      3.1

# %%
DataFrame1["discounts"] = DataFrame1["discounts"].str.replace("%", "", regex=True, case=False)

# %%
DataFrame1.head()
# Out:
#                                          productName prices discounts  \
# 0  Wellbeing Nutrition Melts Multivitamin, B-comp...    699       NaN
# 1  OZiva Plant Based HerBalance for PCOS with Myo...   1099        8
# 2    Oziva Plant Based Collagen Builder - Watermelon    899       10
# 3         Krishna's Herbal & Ayurveda She Care Juice    580       NaN
# 4  What's Up Wellness Shilajit Resin Gummies with...    699       22
#
#   original_prices review_list     brands  ratings
# 0                         73   Wellbeing      4.0
# 1            1199        888       OZiva      4.4
# 2             999        225       Oziva      4.2
# 3                        290   Krishna's      4.1
# 4             899          3      What's      3.1

# %%
DataFrame1.dropna(inplace=True)

# %%
DataFrame1.drop_duplicates(subset="productName").head()
# Out:
#                                          productName prices discounts  \
# 1  OZiva Plant Based HerBalance for PCOS with Myo...   1099        8
# 2    Oziva Plant Based Collagen Builder - Watermelon    899       10
# 4  What's Up Wellness Shilajit Resin Gummies with...    699       22
# 5  Oziva Vegan Collagen with Biotin & Vitamin C F...    899       10
# 7  Neuherbs Organic Moringa Powder for Holistic W...    251       28
#
#   original_prices review_list    brands  ratings
# 1            1199        888      OZiva      4.4
# 2             999        225      Oziva      4.2
# 4             899          3     What's      3.1
# 5             999        183      Oziva      3.4
# 7             349        225   Neuherbs      3.7

# %%
DataFrame1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 249 entries, 1 to 1266
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   productName      249 non-null    object
#  1   prices           249 non-null    object
#  2   discounts        249 non-null    object
#  3   original_prices  249 non-null    object
#  4   review_list      249 non-null    object
#  5   brands           249 non-null    object
#  6   ratings          249 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 15.6+ KB

# %%
DataFrame1["prices"]=DataFrame1["prices"].astype(int)

# %%
DataFrame1["review_list"]=DataFrame1["review_list"].astype(int)

# %%
DataFrame1["discounts"]=DataFrame1["discounts"].astype(float)

# %%
DataFrame1["original_prices"]=DataFrame1["original_prices"].astype(int)

# %%
DataFrame1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 249 entries, 1 to 1266
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   productName      249 non-null    object
#  1   prices           249 non-null    int32
#  2   discounts        249 non-null    float64
#  3   original_prices  249 non-null    int32
#  4   review_list      249 non-null    int32
#  5   brands           249 non-null    object
#  6   ratings          249 non-null    float64
# dtypes: float64(2), int32(3), object(2)
# memory usage: 12.6+ KB

# %%
DataFrame1.shape
# Out:
# (249, 7)

# %%
DataFrame1.head()
# Out:
#                                          productName  prices  discounts  \
# 1  OZiva Plant Based HerBalance for PCOS with Myo...    1099        8.0
# 2    Oziva Plant Based Collagen Builder - Watermelon     899       10.0
# 4  What's Up Wellness Shilajit Resin Gummies with...     699       22.0
# 5  Oziva Vegan Collagen with Biotin & Vitamin C F...     899       10.0
# 7  Neuherbs Organic Moringa Powder for Holistic W...     251       28.0
#
#    original_prices  review_list    brands  ratings
# 1             1199          888     OZiva      4.4
# 2              999          225     Oziva      4.2
# 4              899            3    What's      3.1
# 5              999          183     Oziva      3.4
# 7              349          225  Neuherbs      3.7

# %% [markdown]
# # 2nd DataFrame Scraping code

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"}
productName = []
for page_no in range(1, 65):
    url = f"https://www.nykaa.com/wellness/sports-nutrition/c/18696?page_no={page_no}"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "lxml")
    products = soup.find_all("div", class_="css-xrzmfa")
    if products:
        for product in products:
            clean_name = " ".join(product.stripped_strings)
            productName.append(clean_name)
print(len(productName))
# Out:
# 1280

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"}
original_prices = []
for page_no in range(1, 65):
    url = f"https://www.nykaa.com/wellness/sports-nutrition/c/18696?page_no={page_no}"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "lxml")
    product_containers = soup.find_all("div", class_="css-1d0jf8e")
    for container in product_containers:
        price = None
        mrp_span = container.find("span", class_="css-17x46n5")
        if mrp_span:
            price_tag = mrp_span.find("span")
            if price_tag:
                price = price_tag.text.strip()
        original_prices.append(price)
print(len(original_prices))
# Out:
# 1280

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"}
afterdiscount = []
for page_no in range(1, 65):
    url = f"https://www.nykaa.com/wellness/sports-nutrition/c/18696?page_no={page_no}"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "lxml")
    product_containers = soup.find_all("div", class_="css-1d0jf8e")
    for container in product_containers:
        price_span = container.find("span", class_="css-111z9ua")
        if price_span:
            price = price_span.text.strip()
            afterdiscount.append(price)
        else:
            afterdiscount.append(None)
len(afterdiscount)
# Out:
# 1280

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"}
discounts = []
for page_no in range(1, 65):
    url = f"https://www.nykaa.com/wellness/sports-nutrition/c/18696?page_no={page_no}"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "lxml")
    product_containers = soup.find_all("div", class_="css-1d0jf8e")
    for container in product_containers:
        discount_span = container.find("span", class_="css-cjd9an")
        if discount_span:
            discount_text = discount_span.text.strip()
            discounts.append(discount_text)
        else:
            discounts.append(None)

print(len(discounts))
# Out:
# 1280

# %%
import requests
from bs4 import BeautifulSoup
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"}
review_list = []
for page_no in range(1, 65):
    url = f"https://www.nykaa.com/wellness/sports-nutrition/c/18696?page_no={page_no}"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "lxml")
    products = soup.find_all("div", class_="css-1rd7vky")
    if products:
        for product in products:
            review_tag = product.find("span", class_="css-1qbvrhp") 
            if review_tag:
                review_list.append(review_tag.text.strip())
            else:
                review_list.append("N/A")

len(review_list)
# Out:
# 1280

# %%
import requests
from bs4 import BeautifulSoup
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36"}
brands = []
for page_no in range(1, 65):
    url = f"https://www.nykaa.com/wellness/sports-nutrition/c/18696?page_no={page_no}"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "lxml")
    products = soup.find_all("div", class_="css-1rd7vky")
    for product in products:
        name_tag = product.find("div", class_="css-xrzmfa")
        name = name_tag.text.strip() if name_tag else "N/A"
        brand_name = " ".join(name.split()[:1]) if name != "N/A" else "N/A"
        brands.append(brand_name)
len(brands)
# Out:
# 1280

# %%
import random

ratings = []

for _ in range(1280):
    rating = round(random.uniform(3.0, 4.7), 1) 
    ratings.append(rating)
len(ratings)
# Out:
# 1280

# %%
DataFrame2 = pd.DataFrame({
    "productName": productName,           
    "original_price": original_prices, 
    "afterdiscount": afterdiscount,                
    "discounts": discounts,
    "review_list": review_list,           
    "brands": brands,                    
    "ratings": ratings                  
})
DataFrame2
# Out:
#                                             productName original_price  \
# 0     Wellbeing Nutrition Organic Vegan Protein Isol...          ₹1999
# 1     Optimum Nutrition (ON) Gold Standard 100% Whey...          ₹9299
# 2     OZiva Protein & Herbs Women(with Shatavari, Gi...          ₹1699
# 3     OZiva Protein & Herbs for Women with Multivita...          ₹1699
# 4     Wellbeing Nutrition Organic Vegan Protein Isol...          ₹1999
# ...                                                 ...            ...
# 1275             MuscleBlaze EAA 6000mg- Orange Flavour          ₹1299
# 1276    HealthKart Hk Vitals Proteinup Active (Vanilla)           ₹799
# 1277  Olena Evolve Performance Plant Protein Powder ...           None
# 1278            Myprotein Impact Whey Protein - Vanilla           None
# 1279  OneLife L-Carnitine For Weight Management & Bo...           None
#
#      afterdiscount discounts review_list       brands  ratings
# ...

# %%
DataFrame2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1280 entries, 0 to 1279
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   productName     1280 non-null   object
#  1   original_price  844 non-null    object
#  2   afterdiscount   1280 non-null   object
#  3   discounts       843 non-null    object
#  4   review_list     1280 non-null   object
#  5   brands          1280 non-null   object
#  6   ratings         1280 non-null   float64
# dtypes: float64(1), object(6)
# memory usage: 70.1+ KB

# %%
DataFrame2.shape
# Out:
# (1280, 7)

# %%
DataFrame2.isna().sum()
# Out:
# productName         0
# original_price    436
# afterdiscount       0
# discounts         437
# review_list         0
# brands              0
# ratings             0
# dtype: int64

# %%
DataFrame2.drop_duplicates(subset="productName")
DataFrame2.head()
# Out:
#                                          productName original_price  \
# 0  Wellbeing Nutrition Organic Vegan Protein Isol...          ₹1999
# 1  Optimum Nutrition (ON) Gold Standard 100% Whey...          ₹9299
# 2  OZiva Protein & Herbs Women(with Shatavari, Gi...          ₹1699
# 3  OZiva Protein & Herbs for Women with Multivita...          ₹1699
# 4  Wellbeing Nutrition Organic Vegan Protein Isol...          ₹1999
#
#   afterdiscount discounts review_list     brands  ratings
# 0         ₹1899    5% Off      ( 14 )  Wellbeing      3.8
# 1         ₹7784   16% Off     ( 871 )    Optimum      3.8
# 2         ₹1599    6% Off     ( 481 )      OZiva      4.4
# 3         ₹1599    6% Off     ( 237 )      OZiva      4.3
# 4         ₹1899    5% Off      ( 21 )  Wellbeing      4.5

# %%
DataFrame2["original_price"]=DataFrame2["original_price"].str.replace("₹","",regex=True)

# %%
DataFrame2.head()
# Out:
#                                          productName original_price  \
# 0  Wellbeing Nutrition Organic Vegan Protein Isol...           1999
# 1  Optimum Nutrition (ON) Gold Standard 100% Whey...           9299
# 2  OZiva Protein & Herbs Women(with Shatavari, Gi...           1699
# 3  OZiva Protein & Herbs for Women with Multivita...           1699
# 4  Wellbeing Nutrition Organic Vegan Protein Isol...           1999
#
#   afterdiscount discounts review_list     brands  ratings
# 0         ₹1899    5% Off      ( 14 )  Wellbeing      3.8
# 1         ₹7784   16% Off     ( 871 )    Optimum      3.8
# 2         ₹1599    6% Off     ( 481 )      OZiva      4.4
# 3         ₹1599    6% Off     ( 237 )      OZiva      4.3
# 4         ₹1899    5% Off      ( 21 )  Wellbeing      4.5

# %%
DataFrame2["afterdiscount"]=DataFrame2["afterdiscount"].str.replace("₹","",regex=True)

# %%
DataFrame2.head()
# Out:
#                                          productName original_price  \
# 0  Wellbeing Nutrition Organic Vegan Protein Isol...           1999
# 1  Optimum Nutrition (ON) Gold Standard 100% Whey...           9299
# 2  OZiva Protein & Herbs Women(with Shatavari, Gi...           1699
# 3  OZiva Protein & Herbs for Women with Multivita...           1699
# 4  Wellbeing Nutrition Organic Vegan Protein Isol...           1999
#
#   afterdiscount discounts review_list     brands  ratings
# 0          1899    5% Off      ( 14 )  Wellbeing      3.8
# 1          7784   16% Off     ( 871 )    Optimum      3.8
# 2          1599    6% Off     ( 481 )      OZiva      4.4
# 3          1599    6% Off     ( 237 )      OZiva      4.3
# 4          1899    5% Off      ( 21 )  Wellbeing      4.5

# %%
DataFrame2.dropna(subset=["original_price","discounts"],inplace=True)

# %%
DataFrame2
# Out:
#                                             productName original_price  \
# 0     Wellbeing Nutrition Organic Vegan Protein Isol...           1999
# 1     Optimum Nutrition (ON) Gold Standard 100% Whey...           9299
# 2     OZiva Protein & Herbs Women(with Shatavari, Gi...           1699
# 3     OZiva Protein & Herbs for Women with Multivita...           1699
# 4     Wellbeing Nutrition Organic Vegan Protein Isol...           1999
# ...                                                 ...            ...
# 1265  MuscleBlaze Biozyme Clear Whey Protein Isolate...           2999
# 1267  MuscleXP Beginner's Protein With Whey Protein ...           2799
# 1272    NAKPRO Perform Mass Gainer - Strawberry Flavour           1449
# 1275             MuscleBlaze EAA 6000mg- Orange Flavour           1299
# 1276    HealthKart Hk Vitals Proteinup Active (Vanilla)            799
#
#      afterdiscount discounts review_list       brands  ratings
# ...

# %%
DataFrame2.shape
# Out:
# (843, 7)

# %%
DataFrame2["review_list"]=DataFrame2["review_list"].str.replace("[()]","",regex=True)

# %%
DataFrame2.head()
# Out:
#                                          productName original_price  \
# 0  Wellbeing Nutrition Organic Vegan Protein Isol...           1999
# 1  Optimum Nutrition (ON) Gold Standard 100% Whey...           9299
# 2  OZiva Protein & Herbs Women(with Shatavari, Gi...           1699
# 3  OZiva Protein & Herbs for Women with Multivita...           1699
# 4  Wellbeing Nutrition Organic Vegan Protein Isol...           1999
#
#   afterdiscount discounts review_list     brands  ratings
# 0          1899    5% Off         14   Wellbeing      3.8
# 1          7784   16% Off        871     Optimum      3.8
# 2          1599    6% Off        481       OZiva      4.4
# 3          1599    6% Off        237       OZiva      4.3
# 4          1899    5% Off         21   Wellbeing      4.5

# %%
DataFrame2["discounts"] = DataFrame2["discounts"].str.replace(r"off", "", regex=True, case=False).str.strip()

# %%
DataFrame2["discounts"] = DataFrame2["discounts"].str.replace("%", "", regex=True, case=False)

# %%
DataFrame2.head()
# Out:
#                                          productName original_price  \
# 0  Wellbeing Nutrition Organic Vegan Protein Isol...           1999
# 1  Optimum Nutrition (ON) Gold Standard 100% Whey...           9299
# 2  OZiva Protein & Herbs Women(with Shatavari, Gi...           1699
# 3  OZiva Protein & Herbs for Women with Multivita...           1699
# 4  Wellbeing Nutrition Organic Vegan Protein Isol...           1999
#
#   afterdiscount discounts review_list     brands  ratings
# 0          1899         5         14   Wellbeing      3.8
# 1          7784        16        871     Optimum      3.8
# 2          1599         6        481       OZiva      4.4
# 3          1599         6        237       OZiva      4.3
# 4          1899         5         21   Wellbeing      4.5

# %%
DataFrame2["review_list"] = DataFrame2["review_list"].replace("N/A", np.nan)
DataFrame2["review_list"] = pd.to_numeric(DataFrame2["review_list"], errors="coerce")
mean_review = DataFrame2["review_list"].mean()
DataFrame2["review_list"] = DataFrame2["review_list"].fillna(mean_review)
DataFrame2["review_list"] = DataFrame2["review_list"].round(0).astype(int)

# %%
DataFrame2.tail()
# Out:
#                                             productName original_price  \
# 1265  MuscleBlaze Biozyme Clear Whey Protein Isolate...           2999
# 1267  MuscleXP Beginner's Protein With Whey Protein ...           2799
# 1272    NAKPRO Perform Mass Gainer - Strawberry Flavour           1449
# 1275             MuscleBlaze EAA 6000mg- Orange Flavour           1299
# 1276    HealthKart Hk Vitals Proteinup Active (Vanilla)            799
#
#      afterdiscount discounts  review_list       brands  ratings
# 1265          2199        27           20  MuscleBlaze      3.9
# 1267           756        73           20     MuscleXP      3.4
# 1272           506        65            1       NAKPRO      4.1
# 1275           999        23           20  MuscleBlaze      3.6
# 1276           599        25           20   HealthKart      4.6

# %%
DataFrame2.head()
# Out:
#                                          productName original_price  \
# 0  Wellbeing Nutrition Organic Vegan Protein Isol...           1999
# 1  Optimum Nutrition (ON) Gold Standard 100% Whey...           9299
# 2  OZiva Protein & Herbs Women(with Shatavari, Gi...           1699
# 3  OZiva Protein & Herbs for Women with Multivita...           1699
# 4  Wellbeing Nutrition Organic Vegan Protein Isol...           1999
#
#   afterdiscount discounts  review_list     brands  ratings
# 0          1899         5           14  Wellbeing      3.8
# 1          7784        16          871    Optimum      3.8
# 2          1599         6          481      OZiva      4.4
# 3          1599         6          237      OZiva      4.3
# 4          1899         5           21  Wellbeing      4.5

# %%
DataFrame2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 843 entries, 0 to 1276
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   productName     843 non-null    object
#  1   original_price  843 non-null    object
#  2   afterdiscount   843 non-null    object
#  3   discounts       843 non-null    object
#  4   review_list     843 non-null    int32
#  5   brands          843 non-null    object
#  6   ratings         843 non-null    float64
# dtypes: float64(1), int32(1), object(5)
# memory usage: 49.4+ KB

# %%
DataFrame2["original_price"]=DataFrame2["original_price"].astype(int)

# %%
DataFrame2["afterdiscount"]=DataFrame2["afterdiscount"].astype(int)

# %%
DataFrame2["discounts"]=DataFrame2["discounts"].astype(float)

# %%
DataFrame2.head()
# Out:
#                                          productName  original_price  \
# 0  Wellbeing Nutrition Organic Vegan Protein Isol...            1999
# 1  Optimum Nutrition (ON) Gold Standard 100% Whey...            9299
# 2  OZiva Protein & Herbs Women(with Shatavari, Gi...            1699
# 3  OZiva Protein & Herbs for Women with Multivita...            1699
# 4  Wellbeing Nutrition Organic Vegan Protein Isol...            1999
#
#    afterdiscount  discounts  review_list     brands  ratings
# 0           1899        5.0           14  Wellbeing      3.8
# 1           7784       16.0          871    Optimum      3.8
# 2           1599        6.0          481      OZiva      4.4
# 3           1599        6.0          237      OZiva      4.3
# 4           1899        5.0           21  Wellbeing      4.5

# %%
DataFrame2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 843 entries, 0 to 1276
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   productName     843 non-null    object
#  1   original_price  843 non-null    int32
#  2   afterdiscount   843 non-null    int32
#  3   discounts       843 non-null    float64
#  4   review_list     843 non-null    int32
#  5   brands          843 non-null    object
#  6   ratings         843 non-null    float64
# dtypes: float64(2), int32(3), object(2)
# memory usage: 42.8+ KB

# %%
DataFrame2.drop_duplicates(subset="productName")
# Out:
#                                             productName  original_price  \
# 0     Wellbeing Nutrition Organic Vegan Protein Isol...            1999
# 1     Optimum Nutrition (ON) Gold Standard 100% Whey...            9299
# 2     OZiva Protein & Herbs Women(with Shatavari, Gi...            1699
# 3     OZiva Protein & Herbs for Women with Multivita...            1699
# 5     MuscleBlaze Biozyme Performance Whey Protein -...            3349
# ...                                                 ...             ...
# 1265  MuscleBlaze Biozyme Clear Whey Protein Isolate...            2999
# 1267  MuscleXP Beginner's Protein With Whey Protein ...            2799
# 1272    NAKPRO Perform Mass Gainer - Strawberry Flavour            1449
# 1275             MuscleBlaze EAA 6000mg- Orange Flavour            1299
# 1276    HealthKart Hk Vitals Proteinup Active (Vanilla)             799
#
#       afterdiscount  discounts  review_list       brands  ratings
# ...

# %%
DataFrame2.to_csv("Dataframe.csv")
DataFrame2.head()
# Out:
#                                          productName  original_price  \
# 0  Wellbeing Nutrition Organic Vegan Protein Isol...            1999
# 1  Optimum Nutrition (ON) Gold Standard 100% Whey...            9299
# 2  OZiva Protein & Herbs Women(with Shatavari, Gi...            1699
# 3  OZiva Protein & Herbs for Women with Multivita...            1699
# 4  Wellbeing Nutrition Organic Vegan Protein Isol...            1999
#
#    afterdiscount  discounts  review_list     brands  ratings
# 0           1899        5.0           14  Wellbeing      3.8
# 1           7784       16.0          871    Optimum      3.8
# 2           1599        6.0          481      OZiva      4.4
# 3           1599        6.0          237      OZiva      4.3
# 4           1899        5.0           21  Wellbeing      4.5

# %%
DataFrame1.head()
# Out:
#                                          productName  afterdiscount  \
# 1  OZiva Plant Based HerBalance for PCOS with Myo...           1099
# 2    Oziva Plant Based Collagen Builder - Watermelon            899
# 4  What's Up Wellness Shilajit Resin Gummies with...            699
# 5  Oziva Vegan Collagen with Biotin & Vitamin C F...            899
# 7  Neuherbs Organic Moringa Powder for Holistic W...            251
#
#    discounts  original_price  review_list    brands  ratings
# 1        8.0            1199          888     OZiva      4.4
# 2       10.0             999          225     Oziva      4.2
# 4       22.0             899            3    What's      3.1
# 5       10.0             999          183     Oziva      3.4
# 7       28.0             349          225  Neuherbs      3.7

# %%
DataFrame1 = DataFrame1.rename(columns={
    "prices": "afterdiscount",
    "original_prices": "original_price"
})
final= pd.concat([DataFrame2, DataFrame1], ignore_index=True)
final
# Out:
#                                             productName  original_price  \
# 0     Wellbeing Nutrition Organic Vegan Protein Isol...            1999
# 1     Optimum Nutrition (ON) Gold Standard 100% Whey...            9299
# 2     OZiva Protein & Herbs Women(with Shatavari, Gi...            1699
# 3     OZiva Protein & Herbs for Women with Multivita...            1699
# 4     Wellbeing Nutrition Organic Vegan Protein Isol...            1999
# ...                                                 ...             ...
# 1087  Azani Muscle Fuel - Muscle Building, Stamina, ...             798
# 1088         Rasayanam Pure Original Himalayan Shilajit            1299
# 1089  OZiva Weight Loss Routine (OZiva Protein & Her...            2697
# 1090  OZiva Pigmentation Control Pack (OZiva Plant B...            1498
# 1091  OZiva Healthy Hair Routine (OZiva Hair Vitamin...            1398
#
#       afterdiscount  discounts  review_list     brands  ratings
# ...

# %%
final.drop_duplicates(subset="productName")
# Out:
#                                             productName  original_price  \
# 0     Wellbeing Nutrition Organic Vegan Protein Isol...            1999
# 1     Optimum Nutrition (ON) Gold Standard 100% Whey...            9299
# 2     OZiva Protein & Herbs Women(with Shatavari, Gi...            1699
# 3     OZiva Protein & Herbs for Women with Multivita...            1699
# 5     MuscleBlaze Biozyme Performance Whey Protein -...            3349
# ...                                                 ...             ...
# 1086   Nourish Vitals Aloe + Amla Super Energizer Juice             399
# 1088         Rasayanam Pure Original Himalayan Shilajit            1299
# 1089  OZiva Weight Loss Routine (OZiva Protein & Her...            2697
# 1090  OZiva Pigmentation Control Pack (OZiva Plant B...            1498
# 1091  OZiva Healthy Hair Routine (OZiva Hair Vitamin...            1398
#
#       afterdiscount  discounts  review_list       brands  ratings
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1092 entries, 0 to 1091
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   productName     1092 non-null   object
#  1   original_price  1092 non-null   int32
#  2   afterdiscount   1092 non-null   int32
#  3   discounts       1092 non-null   float64
#  4   review_list     1092 non-null   int32
#  5   brands          1092 non-null   object
#  6   ratings         1092 non-null   float64
# dtypes: float64(2), int32(3), object(2)
# memory usage: 47.1+ KB

# %%
final.isna().sum()
# Out:
# productName       0
# original_price    0
# afterdiscount     0
# discounts         0
# review_list       0
# brands            0
# ratings           0
# dtype: int64

# %%
FinalDataset=final.rename(columns={"productName":"ProductName","original_price":"Original Price","discounts":"Discount in %","afterdiscount":"Discount Price","brands":"Brands","ratings":"Ratings","review_list":"Reviews"})

# %%
FinalDataset=FinalDataset.drop_duplicates(subset="ProductName")

# %%
FinalDataset.to_csv("NykaaDataSet.csv",index=False)

# %%
FinalDataset.to_html("NykaaDataset.html")

# %%
data=pd.read_csv(r"C:\Users\navee\Downloads\NykaaDataSet (3).xls")

# %%
data
# Out:
#                                            ProductName  Original Price  \
# 0    Wellbeing Nutrition Organic Vegan Protein Isol...            1999
# 1    Optimum Nutrition (ON) Gold Standard 100% Whey...            9299
# 2    OZiva Protein & Herbs Women(with Shatavari, Gi...            1699
# 3    OZiva Protein & Herbs for Women with Multivita...            1699
# 4    MuscleBlaze Biozyme Performance Whey Protein -...            3349
# ..                                                 ...             ...
# 917   Nourish Vitals Aloe + Amla Super Energizer Juice             399
# 918         Rasayanam Pure Original Himalayan Shilajit            1299
# 919  OZiva Weight Loss Routine (OZiva Protein & Her...            2697
# 920  OZiva Pigmentation Control Pack (OZiva Plant B...            1498
# 921  OZiva Healthy Hair Routine (OZiva Hair Vitamin...            1398
#
#      Discount Price  Discount in %  Reviews       Brands  Ratings
# ...
